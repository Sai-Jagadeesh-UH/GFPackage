# %%
from Meta_Munge import getMetaDf
from OA_Munge import getOALocs

# %%
from OA_Munge import getConcatOA, pushOASilver, pushOAGold

# %%
from NN_Munge import getConcatNN, getNNLocs

# %%
df = await getConcatNN()
df
# Out:
# shape: (848, 9)
# ┌────────────┬───────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Effective_ ┆ Effective ┆ Loc_Prop ┆ Loc_Name  ┆ … ┆ Direction ┆ Accountin ┆ Posting_D ┆ PipeCode │
# │ From_DateT ┆ _End_Date ┆ ---      ┆ ---       ┆   ┆ _Of_Flow  ┆ g_Physinc ┆ ateTime   ┆ ---      │
# │ ime        ┆ Time      ┆ str      ┆ str       ┆   ┆ ---       ┆ al_Indica ┆ ---       ┆ str      │
# │ ---        ┆ ---       ┆          ┆           ┆   ┆ str       ┆ tor       ┆ str       ┆          │
# │ str        ┆ str       ┆          ┆           ┆   ┆           ┆ ---       ┆           ┆          │
# │            ┆           ┆          ┆           ┆   ┆           ┆ str       ┆           ┆          │
# ╞════════════╪═══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 03/18/2026 ┆ 03/19/202 ┆ 70004    ┆ Dominion  ┆ … ┆ D         ┆ P         ┆ 03/20/202 ┆ TE       │
# ...

# %%
LocsNN = await getNNLocs(df)
